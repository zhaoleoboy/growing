# %%
import pandas as pd
from fbprophet import Prophet

# %%
df = pd.read_csv('../datas/prophet/example_wp_log_peyton_manning.csv')
df.tail()
# Out:
#               ds          y
# 2900  2016-01-16   7.817223
# 2901  2016-01-17   9.273878
# 2902  2016-01-18  10.333775
# 2903  2016-01-19   9.125871
# 2904  2016-01-20   8.891374

# %%
len(df)
# Out:
# 2905

# %%
# Python
m = Prophet()
m.fit(df)
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /root/tools/anaconda3/envs/ts/lib/python3.5/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
# Python
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#              ds
# 3265 2017-01-15
# 3266 2017-01-16
# 3267 2017-01-17
# 3268 2017-01-18
# 3269 2017-01-19

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 3265 2017-01-15  8.206055    7.458003    8.906637
# 3266 2017-01-16  8.531073    7.825896    9.291229
# 3267 2017-01-17  8.318475    7.620148    9.076151
# 3268 2017-01-18  8.151084    7.410617    8.829657
# 3269 2017-01-19  8.163015    7.402217    8.874632

# %%
fig1 = m.plot(forecast)

# %%
fig2 = m.plot_components(forecast)

# %%
from fbprophet.plot import plot_plotly
import plotly.offline as py
py.init_notebook_mode()

fig = plot_plotly(m, forecast)  # This returns a plotly Figure
py.iplot(fig)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-71ab2fe2e774> in <module>
# ----> 1 from fbprophet.plot import plot_plotly
#       2 import plotly.offline as py
#       3 py.init_notebook_mode()
#       4
#       5 fig = plot_plotly(m, forecast)  # This returns a plotly Figure
#
# ImportError: cannot import name 'plot_plotly'
